# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
df=pd.read_csv('https://github.com/andvise/DataAnalyticsDatasets/blob/95fa5942f1aa159751076ca291fb4799a6deacf7/coffee.csv?raw=true')
df
# Out:
#     CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0             8                 2  Before coding                 Yes
# 1             3                 2  Before coding                 Yes
# 2             5                 3   While coding                  No
# 3             8                 2  Before coding                  No
# 4            10                 3   While coding           Sometimes
# ..          ...               ...            ...                 ...
# 95            6                 2  Before coding                 Yes
# 96            4                 1  Before coding           Sometimes
# 97           10                 3  Before coding                 Yes
# 98            2                 2   While coding           Sometimes
# 99           10                 4  Before coding           Sometimes
#
#                   CoffeeType CoffeeSolveBugs  Gender  Country  AgeRange
# ...

# %%
df.to_csv('')

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (100, 9)
# CodingHours             int64
# CoffeeCupsPerDay        int64
# CoffeeTime             object
# CodingWithoutCoffee    object
# CoffeeType             object
# CoffeeSolveBugs        object
# Gender                 object
# Country                object
# AgeRange               object
# dtype: object

# %%
print(df['CoffeeTime'].dtype)
# Out:
# object

# %%
df.columns
# Out:
# Index(['CodingHours', 'CoffeeCupsPerDay', 'CoffeeTime', 'CodingWithoutCoffee',
#        'CoffeeType', 'CoffeeSolveBugs', 'Gender', 'Country', 'AgeRange'],
#       dtype='object')

# %%
df=pd.read_csv('https://github.com/andvise/DataAnalyticsDatasets/blob/95fa5942f1aa159751076ca291fb4799a6deacf7/titanic.csv?raw=True')

# %%
print(df.shape[0])
print(df.shape[0] * df.shape[1])
print(df.size)
print(df.columns)
print(df.dtypes)
# Out:
# 887
# 7983
# 7983
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare'],
#       dtype='object')
# PassengerId                  int64
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard    float64
# Fare                       float64
# dtype: object

# %%
df1=pd.read_csv("https://github.com/andvise/DataAnalyticsDatasets/blob/95fa5942f1aa159751076ca291fb4799a6deacf7/titanic.csv?raw=true")
df1
df1['Pclass'].mode()
dir(df1)
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %%
df1['Age'].max()
df1['Age'].describe()
# Out:
# count    887.000000
# mean      29.471443
# std       14.121908
# min        0.420000
# 25%       20.250000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df1.head(2)
df1.tail(3)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 884          885         0       3  Miss. Catherine Helen Johnston  female
# 885          886         1       1            Mr. Karl Howell Behr    male
# 886          887         0       3              Mr. Patrick Dooley    male
#
#       Age  Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 884   7.0                        1                      2.0  23.45
# 885  26.0                        0                      0.0  30.00
# 886  32.0                        0                      0.0   7.75

# %%
df1['Age'].max()-df1['Age'].min()
# Out:
# 79.58

# %%
df1.Age.max()-df1.Age.min()
# Out:
# 79.58

# %%
round(df1['Survived'].sum()/df1.shape[0],2)
df1['Survived'].sum()/len(df1)
# Out:
# 0.3855693348365276

# %%
df1['Survived'].mean() * 100
# Out:
# 38.55693348365276

# %%
df1['Age'].head(50).mean()
# Out:
# 26.36

# %%
df1=pd.read_csv("https://github.com/andvise/DataAnalyticsDatasets/blob/95fa5942f1aa159751076ca291fb4799a6deacf7/flights.csv?raw=true")
df1
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df1.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
df1=df1[['year', 'month', 'day', 'hour', 'minute','dep_time', 'sched_dep_time', 'dep_delay',
       'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
       'tailnum', 'origin', 'dest', 'air_time', 'distance',
       'time_hour']]
df1
# Out:
#         year  month  day  hour  minute  dep_time  sched_dep_time  dep_delay  \
# 0       2013      1    1     5      15     517.0             515        2.0
# 1       2013      1    1     5      29     533.0             529        4.0
# 2       2013      1    1     5      40     542.0             540        2.0
# 3       2013      1    1     5      45     544.0             545       -1.0
# 4       2013      1    1     6       0     554.0             600       -6.0
# ...      ...    ...  ...   ...     ...       ...             ...        ...
# 336771  2013      9   30    14      55       NaN            1455        NaN
# 336772  2013      9   30    22       0       NaN            2200        NaN
# 336773  2013      9   30    12      10       NaN            1210        NaN
# 336774  2013      9   30    11      59       NaN            1159        NaN
# 336775  2013      9   30     8      40       NaN             840        NaN
#
# ...

# %%
rows_before=len(df1)
rows_before
# Out:
# 336776

# %%
df1.clean=df1.dropna()
rows_before-len(df1.clean)
# Out:
# 9430

# %%
df1.dropna(inplace=True)

# %%
df1.dropna(axis=1)
df.dropna(how="all")

# %%
df1[10:12]
# Out:
#     year  month  day  hour  minute  dep_time  sched_dep_time  dep_delay  \
# 10  2013      1    1     6       0     558.0             600       -2.0
# 11  2013      1    1     6       0     558.0             600       -2.0
#
#     arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 10     849.0             851       -2.0      B6      49  N793JB    JFK  PBI
# 11     853.0             856       -3.0      B6      71  N657JB    JFK  TPA
#
#     air_time  distance             time_hour
# 10     149.0      1028  2013-01-01T06:00:00Z
# 11     158.0      1005  2013-01-01T06:00:00Z

# %% [markdown]
# # New section
